# %% [markdown]
# #    <center>Informatique 1A - INF tc3 (Projet d'application Web)</center>

# %% [markdown]
# ## <center style="color: #66d">TD 1<br>Gestion du projet avec gitlab / Base de données SQLite</center>
# <center>Important : ce fichier doit être ouvert dans Jupyter Notebook</center>

# %% [markdown]
# Dans le cadre de ce TD :
# * Nous regarderons comment utiliser le serveur _gitlab_ de l'Ecole Centrale pour créer un environnement de développement collaboratif pour votre projet.
# * Nous créerons une base de données et développerons du code Python pour lire des données et les réutiliser pour obtenir des représentations graphiques.

# %% [markdown]
# ### 1. Gestion du projet avec gitlab (60 min.)

# %% [markdown]
# Vous avez consitué avant ce TD un groupe de projet avec 4 ou 5 camarades. Si ce n'est pas le cas, dépéchez-vous d'aller vous inscrire sur <a href="http://pedagogie1.ec-lyon.fr/">Pedagogie1</a> section "Inscription aux sous-groupes de projet"
#
# Pour bien gérer le développement collaboratif de votre projet vous devrez utiliser le <b><a href="https://gitlab.ec-lyon.fr/">serveur gitlab de l'Ecole Centrale</a></b>. L'usage de gitlab par __tous__ les membres du groupe de projet fera partie des critères d'évaluation.
#
# <b>ATTENTION : veillez à bien vous connecter avec votre compte "ECL". N'utilisez pas d'identifiants externes !</b>

# %% [markdown]
# __1.1. Prise en main de gitlab et de GitHub Desktop :__
#
# Si vous ne l'avez pas déjà fait dans le cours INF tc2...
# <div style="background-color:#eef;padding:10px;border-radius:3px">
# Suivez le <a href="https://gitlab.ec-lyon.fr/edelland/inf_tc2_2025-2026-S5/-/blob/main/Tutoriel_gitlab/tutoriel_gitlab.md"> tutoriel sur git/gitlab et l'outil GitHub Desktop</a>

# %% [markdown]
# <b>Important :</b> Au moment de l'instatllation de GitHub Desktop, ne créez pas de compte GitHub ou ne vous connectez pas à votre compte GitHub, mais sautez l'étape en cliquant sur le bouton discret "Skip this step" :<br>
# <img src="figures/TD1-Ecran-config.jpg">

# %% [markdown]
# A la suite de ce tutoriel vous devez disposer :
# * d'un compte personnel opérationnel sur le <a href="https://gitlab.ec-lyon.fr">serveur gitlab de l'Ecole</a>
# * du logiciel GitHub Desktop installé sur votre machine

# %% [markdown]
# __1.2. Création de votre environnement de projet :__
#
# Dans votre groupe une des personnes (appelons-la <i>chef·fe de projet</i>) va créer le dépôt de travail sur son espace personnel dans le <a href="https://gitlab.ec-lyon.fr">serveur gitlab de l'Ecole</a> et le partager avec les autres membres du groupe.
#
# <div style="background-color:#eef;padding:10px;border-radius:3px">
# La personne qui est <i>chef·fe de projet</i> :<ul>
# <li>Crée un nouveau projet dans son espace personnel sur "gitlab.ec-lyon.fr" en lui donnant un nom explicite contenant la lettre du projet (A, B, C, D, E). L'accès à ce projet devra être réglé sur "<b>private</b>".
#            <li>En créant ce projet, elle crée un fichier README.MD contenant le titre du sujet et son nom sur une 2ème ligne.
#     <li>Dans l'onglet "membres" elle invite les autres membres du groupe <b>ainsi que le chargé de TD</b> en leur donnant le statut "<b>developer</b>"
#
# </ul>
#     </div>
#     <br>
#     <div style="background-color:#eef;padding:10px;border-radius:3px">
#     <p>Toutes les autres personnes du groupe :<ul>
#     <li>Vérifient qu'elles ont bien les droits suffisants sur cet espace
#     <li>Clonent ce dossier sur leur ordinateur personnel avec <i>Github Desktop</i> (ou les commandes <i>git</i>),.
#     </ul>
#      </div>

# %% [markdown]
# __1.3 Worflow de travail collaboratif :__
#
# Il faut d'abord répartir les rôles au sein de votre groupe et savoir "qui fait quoi". Le consigner par écrit, par exemple dans la page README.md du dépôt, est probablement une bonne idée.
#
# Ensuite chaque membre du groupe travaille sur une copie locale sur sa machine. Lorsqu'il estime avoir atteint un niveau suffisament stable de son code, il fait un _commit_ puis un _push_ pour publier ses modifications sur le dépôt gitlab. Les autres peuvent alors faire un _pull_ pour récupérer la mise à jour.
#
# L'approche la plus simple consiste à autoriser les "developer" a _pusher_ directement dans la branche _master_.
#
# <div style="background-color:#eef;padding:10px;border-radius:3px">
# Pour cela, la·le <i>chef·fe de projet</i> doit éditer les permissions sur cette branche :<ul>
# <li> dans l'interface de gitlab, ouvrir le menu "Settings | Repository"
# <li> dans la section "Protected branches", dans le tableau cliquer sur le bouton "Unprotect" pour la branche <i>master</i>
#     </ul>
# </div>

# %% [markdown]
# Sinon (fonctionnement par défaut), avec le statut "developer", les membres doivent créer une nouvelle branche à chaque _push_ et doivent demander un _merge request_ pour que le _chef de projet_ (qui a le statut "maintener") fasse la fusion avec la branche "master". S'il y a des conflits à la fusion, le _chef de projet_ doit les régler pour finaliser le _merge_
#
# Alternativement la·le _chef·fe de projet_ peut donner le statut "maintener" à tous les membres du groupe (ce qui donne tous les droits à tout le monde) mais à ses riques et périls :-)

# %% [markdown]
# <div style="background-color:#eef;padding:10px;border-radius:3px">
#     Pour tester le workflow, faites l'exercice suivant.
# Pour chaque membre :<ul>
#     <li>Faire un <i>pull</i> du dépôt avec <i>Github Desktop</i> (normalement déjà fait par le <i>clone</i> à la section 1.2)
#     <li>Editer en local le fichier README.MD avec un éditeur de texte pour rajouter son nom sur une nouvelle ligne à la fin du fichier
#     <li>Faire un <i>commit</i> de ses changements avec <i>Github Desktop</i>
#     <li>Faire un <i>push</i> de ses modifications sur le dépôt du projet. Si d'autres membres ont fait un <i>push</i> avant vous, vous serez obligé·e de refaire un <i>pull</i> de ces modifications pour vous resynchroniser avec le dépôt. Dans ce cas vous devrez d'abord résoudre les éventuels <i>merge conflicts</i> avec l'éditeur de <i>Github Desktop</i> avant de pouvoir retenter votre <i>push</i>...
# </ul>
#     </div>

# %% [markdown]
# ### 2. Création d'une base de données SQLite (15 min.)

# %% [markdown]
# La base de données sera au format SQLite _(fichier .sqlite)._ Toutes les opérations sur une base de données de ce type peuvent être effectuées depuis Python via le module _sqlite3_.
#
# Nous utiliserons l'outil "DB Browser for SQLite".
#
# <div style="background-color:#eef;padding:10px;border-radius:3px">
# Télécharger et installer <a href="http://sqlitebrowser.org/">DB Browser for SQLite</a> en suivant les instructions d'installation en fonction de votre système d'exploitation.
# <p>
# Démarrer DB Browser for SQLite.

# %% [markdown]
# __2.1. Création d'une base SQLite :__
# <div style="background-color:#eef;padding:10px;border-radius:3px">
# <p>Dans DB Browser, cliquer sur le bouton "New Database" pour créer une base de donnée :<ul>
# <li>Naviguer dans l'arborescence pour se placer dans le répertoire de travail du TD1.
# <li>Nommer cette base "ter.sqlite" et l'enregistrer.
# </ul>

# %% [markdown]
# __2.2. Importation des données :__
#
# Dans ce TD nous travaillons sur des données ouvertes fournies par la SCNF et récupérées sur son portail https://data.sncf.com. Le fichier pris comme exemple contient les statistiques sur la régularité mensuelle des circulations des TER de janvier 2013 à nos jours.
#
# Le fichier `regularite-mensuelle-ter.csv`  dont vous avez besoin se trouve normalement dans votre répertoire de travail (car il est dans le dossier du TD1 que vous avez cloné avec git ou décompacté si vous avez téléchargé un ZIP).
#
# Ce fichier est au format <a href="https://fr.wikipedia.org/wiki/Comma-separated_values">CSV</a> (Comma-Separated Values). Il s'agit d'un fichier contenant du texte (qui peut à ce titre être ouvert et consulté à l'aide du bloc-notes) qui représente un tableau de  données, dont chaque ligne contient une liste de valeurs séparées par des virgules (dans la version originelle, mais d'autres <i>caractères séparateurs</i> peuvent être utilisés).
#
# Le contenu du fichier `regularite-mensuelle-ter.csv` est constitué de données séparées par le caractère `;` (<i>point-virgule</i>). Lorsqu'une valeur contient elle-même le caractère séparateur, cette valeur est délimitée par des caractères `"` (<i>guillemets anglais</i>).
#
# Ce fichier est encodé en <a href="https://fr.wikipedia.org/wiki/UTF-8">UTF-8</a>. C'est la convention choisie pour représenter les caractères alphabétiques et autres, par un code numérique sur le disque et/ou dans la mémoire de l'ordinateur.

# %% [markdown]
# <div style="background-color:#eef;padding:10px;border-radius:3px">
# Dans le menu <i>Fichier</i> choisir la fonction "Importer > Table depuis un fichier CSV..."<br>
# Ouvrir le fichier <tt>regularite-mensuelle-ter.csv</tt><br>
# Un boite de dialogue s'ouvre :<ul>
# <li>cocher la case "Nom des Col. en 1ère ligne"
# <li>choisir comme "Séparateur de champs" = ";"
# <li>choisir pour "Encodage" = "UTF-8"
# </ul>
# Pensez à cliquer sur le bouton "Enregistrer les modifications".

# %% [markdown]
# Normalement vous devez obtenir la structure suivante :
# <img src="figures/TD1-schemaDB.png">
#
# Remarque : il se pourrait que les types des champs ne soit pas détectés et qu'ils soient tous "TEXT". Ce n'est pas un problème car on pourra faire les conversions en Python.
#
# Et en cliquant sur "Parcourir les données" vous pouvez parcourir le contenu de la table :
# <img src="figures/TD1-contentDB.png">

# %% [markdown]
# La description des différents champs est disponible ici (section Modèle de données) :
# __https://ressources.data.sncf.com/explore/dataset/regularite-mensuelle-ter/information/?disjunctive.region__

# %% [markdown]
# ### 3. Lecture des données et premières requêtes SQL (15 min.)

# %% [markdown]
# L'accès à une base de données SQLite se fait en python en important le module `sqlite3` et en ouvrant une connexion avec la base. La documentation est accessible ici : __https://docs.python.org/3.8/library/sqlite3.html__

# %% [markdown]
# Pour exécuter des requêtes SQL il faut créer un objet `cursor` et appeler la méthode `execute`. les résultats sont récupérés par la méthode `fetchall` (on pourrait aussi utiliser les méthodes `fetchone` et `fetchmany`). Normalement le code suivant doit retourner le contenu de la base sous forme d'une liste de tuples.

# %%
import os
import sqlite3

# ouverture d'une connexion avec la base de données après vérification de sa présence
if not os.path.exists('ter.sqlite'):
    raise FileNotFoundError("BD ter.sqlite non trouvée !")
conn = sqlite3.connect('ter.sqlite')

c = conn.cursor()
c.execute("SELECT * FROM 'regularite-mensuelle-ter'")
r = c.fetchall()
for a in r:
    print (a)

# %% [markdown]
# En vous appuyant sur la documentation du langage SQL : __https://sqlite.org/lang.html__, réaliser les quelques exercices suivants.

# %% [markdown]
# <div style="background-color:#eef;padding:10px;border-radius:3px">
# <b>3.1.</b> Ecrivez un programme Python qui affiche la liste des régions présentes dans la table.

# %%
# votre code ici

# %% [markdown]
# Vous remarquerez qu'il y a trop de Régions... En effet, il y a les anciennes et les nouvelles régions et même 3 pseudos-régions !

# %% [markdown]
# <div style="background-color:#eef;padding:10px;border-radius:3px">
# <b>3.2.</b> Ecrivez un programme Python qui affiche le nombre total de trains arrivés en retard pour la région Rhône-Alpes pour l'année 2015.
#
# _Remarque_ : la date est stockée dans le champ `Date` sous forme "AAAA-MM" ou AAAA est l'année et MM le mois.

# %%
# votre code ici

# %% [markdown]
# ### 4. Tracé de courbes de régularité des TER avec matplotlib (30 min.)

# %% [markdown]
# Après ces quelques exemples basiques, on va chercher à visualiser les données de notre table sous formes de courbes ce qui est bien plus parlant que des tableaux de chiffres.

# %% [markdown]
# <div style="background-color:#eef;padding:10px;border-radius:3px">
# <b>4.1.</b> Ecrivez un programme Python qui récupère dans la table <tt>regularite-mensuelle-ter</tt> le contenu des champs <tt>Date</tt> et <tt>Taux de régularité</tt>,  mois par mois, dans l'ordre, pour la région Rhône-Alpes puis les affiche.

# %%
# votre code ici

# %% [markdown]
# Pour tracer des courbes nous utilisons `pyplot` de la bibliothèque standard `matplotlib`. On consultera utilement <a href="https://matplotlib.org/stable/tutorials/pyplot.html">ce tutoriel</a> et <a href="https://matplotlib.org/stable/api/pyplot_summary.html">la documentation complète</a>.
#
# Remarque : pour un affichage correct de l'axe des abscisses, il faut au prélable convertir la date du format "année-mois" au format ___date___ de la bibliothèque Python __<a href="https://docs.python.org/3/library/datetime.html">datetime</a>__.

# %% [markdown]
# <div style="background-color:#eef;padding:10px;border-radius:3px">
# <b>4.2.</b>  En vous référant au <a href="https://matplotlib.org/stable/tutorials/pyplot.html">tutoriel pyplot</a>, tracez la courbe de régularité correspondant à ces données.
#
# <img src="figures/TD1-graph1.png">

# %%
# votre code ici

# %% [markdown]
# <div style="background-color:#eef;padding:10px;border-radius:3px">
#     <b>4.3.</b> Vous pouvez améliorez l'affichage en utilisant les possibilités de matplotlib : titre, grille, noms des axes, légende, etc. et obtenir un affichage plus approprié.
#
# <img src="figures/TD1-graph2.png">

# %%
# votre code ici

# %% [markdown]
# ---
# ---
# ## Annexes (travail facultatif)

# %% [markdown]
# ### A. Création de la base de données par programme
#
# L'objectif de cette partie est strictement similaire à la section 1 mais sans utiliser l'outil DB Browser for SQLite. Il s'agit donc de récupérer les données qui se trouvent dans le fichier regularite-mensuelle-ter.csv et de les importer dans une base SQLite en utilisant uniquement des fonctions Python.
#
# #### a) Lecture d'un fichier de données au format CSV en python

# %% [markdown]
# <div style="background-color:#eef;padding:10px;border-radius:3px">
# <b>A.1 -</b>
# En vous aidant de la <a href="https://docs.python.org/3/library/csv.html">doc python</a> pour lire un fichier csv, reproduisez le premier exemple de programme du § 14.1.1 en l'adaptant pour lire le fichier <tt>regularite-mensuelle-ter.csv</tt>. N'oubliez pas de préciser le caractère séparateur <i>(delimiter)</i> et celui servant à délimiter les valeurs <i>(quotechar)</i>. Si vous observez des caractères bizarres dans le résultat, consultez la <a href="https://docs.python.org/3.4/howto/unicode.html#reading-and-writing-unicode-data">doc python</a> et spécifiez le format du fichier dans l'instruction <tt>open</tt>.
#
# Vous devriez observer un résultat similaire à celui-ci :
#     <img src="figures/TD1-CSV.png">
#     <p><b>N.B.</b> Une fois la liste obtenue, si elle vous paraît trop longue vous pouvez cliquer dans la colonne de gauche pour la replier et éviter d'encombrer la fenêtre du sujet...

# %%
# votre code ici

# %% [markdown]
# #### b) Création d'une base de donnée SQLite en python

# %% [markdown]
# <div style="background-color:#eef;padding:10px;border-radius:3px">
# <b>A.2 -</b>
# En vous aidant du premier exemple de code de la <a href="https://docs.python.org/3/library/sqlite3.html">doc python</a> sur l'utilisation de bases de données SQLite, créez une base de données nommée <tt>ter2.sqlite</tt> et observez dans le répertoire du TD l'appartion du fichier correspondant après exécution du code.

# %%
# votre code ici

# %% [markdown]
# <div style="background-color:#eef;padding:10px;border-radius:3px">
# <b>A.3 -</b>
# Toujours en vous basant sur la <a href="https://docs.python.org/3/library/sqlite3.html">doc python</a>, ainsi que sur la <a href="https://sqlite.org/lang.html">syntaxe SQL</a> supportée par la base SQLite, créez une table nommée <tt>regularite-mensuelle-ter</tt> avec les champs suivants :
# <pre style="background-color: transparent">
# 	Date                             // type texte,
# 	Région                           // type texte,
# 	Nombredetrainsprogrammés         // type entier
# 	Nombredetrainsayantcirculé       // type entier
# 	Nombredetrainsannulés            // type entier
# 	Nombredetrainsenretardàlarrivée  // type entier
# 	Tauxderégularité                 // type réel
# 	Nombredetrainsàlheurepouruntrainenretardàlarrivée  // type réel
# 	Commentaires                     // type texte
# </pre>
# <p><b>N.B.</b> Pour permettre l'exécution répétée de votre cellule de code, ajoutez une instruction SQL pour supprimer la table si elle existe, avant de la recréer...

# %%
# votre code ici

# %% [markdown]
# Pour vérifier la bonne création de la base de donnée ter2.sqlite, ouvrez-la avec l'outil `DB Browser for SQLite`

# %% [markdown]
# #### c) Remplissage de la table de régularité

# %% [markdown]
# <div style="background-color:#eef;padding:10px;border-radius:3px">
# <b>A.4 -</b>
# A partir du code de la question A.1 permettant de lire le fichier CSV, créez un programme permettant d'insérer les données dans la table `regularite-mensuelle-ter`.
#
# Vérifiez l'apparition des données et la bonne exécution de votre programme à l'aide de `DB Browser for SQLite`

# %%
# votre code ici

# %% [markdown]
# A partir de ce point on a une base de donnée similaire à celle créée dans la section 1.

# %% [markdown]
# ### B. Afficher plusieurs courbes sur le même graphique

# %% [markdown]
# En complément de l'exercice 4.1, on vous propose d'afficher 6 courbes de régularité sur le même graphique.<br><br>
#
#
# <div style="background-color:#eef;padding:10px;border-radius:3px">
# <b>B.1 -</b>
# Pour les 6 régions définies dans la liste ci-dessous, affichez les courbes de régularités dans la couleur associée sur le même graphique.
#
# <img src="figures/TD1-graph3.png">

# %%
# Definition des régions et des couleurs de tracé
regions = [("Rhône Alpes","blue"), ("Auvergne","green"), ("Auvergne-Rhône-Alpes","cyan"), ('Bourgogne',"red"), 
           ('Franche Comté','orange'), ('Bourgogne-Franche-Comté','olive') ]

# %%
# votre code ici
