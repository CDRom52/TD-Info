# %% [markdown]
# #    <center>Informatique 1A - INF tc3 (Projet d'application Web)</center>

# %% [markdown]
# ## <center style="color: #66d">TD 4 (fin de séance)<br>Lancement du projet</center>
# <center>Important : ce fichier doit être ouvert dans Jupyter Notebook</center>

# %% [markdown]
# ### 1. Sujets des projets
#
# Les sujets sont disponibles sur le serveur https://pedagogie1.ec-lyon.fr.
#
# Lire attentivement le document : __projets.pdf__
#
# Pour chacun des projets vous disposez d'un fichier ZIP contenant les différents fichiers de données (au format CSV) ainsi qu'un documenent détaillant les attendus de votre projet et donnant des précisions sur les données fournies.

# %% [markdown]
# ### 2. Application fournie

# %% [markdown]
# Afin de vous fournir un squelette d’application comme point de départ, une application basique est disponible dans le dossier « __TD4/regularite-TER__ ».
#
# Cet exemple correspond au corrigé du dernier exercice du TD n°3.
#
# Vous __devez__ partir de ce corrigé comme point de départ pour développer votre propre application. Voir les détails dans le document __projets.pdf__.
